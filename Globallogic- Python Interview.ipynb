# %%
# Find 2nd highest number in one pass from an unsorted array of integers

# input_list = [8,9,3,1,2,10,15,25, 100, 200, 150]
# # Desired output : 7
# max_value = max(input_list)
# min_value = min(input_list)
# print(f"Highest no is : {max_value}")

# for i in range(max_value-1, min_value-1,-1):
#     if i in input_list:
#         print(f"Second highest no is {i}")
#         break


# Rearrage the array 
# Rearrange the given Array in maximun,minimum form.
# Input: arr[] = {1, 2, 3, 4, 5, 6, 7} 
# Output: arr[] = {7, 1, 6, 2, 5, 3, 4}


# arr = [1, 2, 3, 4, 5, 6, 7] 
# # print(arr)
# length_of_array = len(arr)
# # print(length_of_array)
# new_arr = []
# for i in range(0, int(len(arr)/2)+1):
#     last_val = length_of_array-1-i
#     # print(arr[i],arr[last_val])
#     # print("last val",last_val, i)
#     if last_val != i:
#         new_arr.append(arr[last_val])
#     new_arr.append(arr[i])

# print(new_arr)
    

# WEB SERVER
# HTTP REQUEST
# !
# Session middleware
# Security Middleware
# Custom Middleware      
# |
# View 

# def generate_number(number_stop):
#     for i in range(number_stop):
#         yield i
    

# value = generate_number(1000)
# print(value)
# for i in value:
#     print(i)

# find first non-repeater i.e 
# input_string = "abcdefghabcde"
# hashmap = {}
# # output_string = "b"
# for char_ in input_string:
#     hashmap[char_] = hashmap.get(char_, 0)+1

# for i in hashmap:
#     if hashmap[i] == 1:
#         print(i)
#         break
